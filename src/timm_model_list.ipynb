# %% [markdown]
# # timm model list
#
# You can find details on the model lists at these links:
# - https://github.com/rwightman/pytorch-image-models#models
# - https://rwightman.github.io/pytorch-image-models/models/

# %%
import timm

pre_trained_models = timm.list_models(pretrained=True)
all_models = timm.list_models(pretrained=False)

# %%
len(pre_trained_models)
# Out:
# 592

# %%
len(all_models)
# Out:
# 739

# %%
# List all pretrained models
pre_trained_models
# Out:
# ['adv_inception_v3',
#  'bat_resnext26ts',
#  'beit_base_patch16_224',
#  'beit_base_patch16_224_in22k',
#  'beit_base_patch16_384',
#  'beit_large_patch16_224',
#  'beit_large_patch16_224_in22k',
#  'beit_large_patch16_384',
#  'beit_large_patch16_512',
#  'botnet26t_256',
#  'cait_m36_384',
#  'cait_m48_448',
#  'cait_s24_224',
#  'cait_s24_384',
#  'cait_s36_384',
#  'cait_xs24_384',
#  'cait_xxs24_224',
#  'cait_xxs24_384',
#  'cait_xxs36_224',
#  'cait_xxs36_384',
#  'coat_lite_mini',
#  'coat_lite_small',
#  'coat_lite_tiny',
#  'coat_mini',
#  'coat_tiny',
#  'convit_base',
#  'convit_small',
#  'convit_tiny',
#  'convmixer_768_32',
#  'convmixer_1024_20_ks9_p14',
#  'convmixer_1536_20',
#  'convnext_base',
#  'convnext_base_384_in22ft1k',
#  'convnext_base_in22ft1k',
#  'convnext_base_in22k',
#  'convnext_large',
#  'convnext_large_384_in22ft1k',
#  'convnext_large_in22ft1k',
#  'convnext_large_in22k',
#  'convnext_small',
#  'convnext_tiny',
# ...

# %%
# List models which don't have pre-trained weights
set(all_models) - set(pre_trained_models)
# Out:
# {'botnet50ts_256',
#  'convnext_tiny_hnf',
#  'cspdarknet53_iabn',
#  'cspresnet50d',
#  'cspresnet50w',
#  'cspresnext50_iabn',
#  'darknet53',
#  'densenet121d',
#  'densenet264',
#  'densenet264d_iabn',
#  'eca_nfnet_l3',
#  'eca_vovnet39b',
#  'ecaresnet200d',
#  'ecaresnext26t_32x4d',
#  'ecaresnext50t_32x4d',
#  'efficientnet_b2a',
#  'efficientnet_b3a',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_b8',
#  'efficientnet_cc_b0_4e',
#  'efficientnet_cc_b0_8e',
#  'efficientnet_cc_b1_8e',
#  'efficientnet_l2',
#  'efficientnet_lite1',
#  'efficientnet_lite2',
#  'efficientnet_lite3',
#  'efficientnet_lite4',
#  'efficientnetv2_l',
#  'efficientnetv2_m',
#  'efficientnetv2_s',
#  'efficientnetv2_xl',
#  'ese_vovnet19b_slim',
#  'ese_vovnet19b_slim_dw',
#  'ese_vovnet39b_evos',
#  'ese_vovnet57b',
#  'ese_vovnet99b',
#  'ese_vovnet99b_iabn',
#  'ghostnet_050',
#  'ghostnet_130',
#  'gmixer_12_224',
#  'gmlp_b16_224',
#  'gmlp_ti16_224',
# ...
